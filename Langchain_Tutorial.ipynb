# %%
pip install -r Requirements.txt
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# cd C:\Users\ggsag\OneDrive\Desktop\Test 1

# %%
pip install langchain
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/960.7 kB ? eta -:--:--
#      - -------------------------------------- 30.7/960.7 kB ? eta -:--:--
#      - -------------------------------------- 30.7/960.7 kB ? eta -:--:--
#      ---- ------------------------------- 122.9/960.7 kB 901.1 kB/s eta 0:00:01
#      ---- ------------------------------- 122.9/960.7 kB 901.1 kB/s eta 0:00:01
#      -------- --------------------------- 225.3/960.7 kB 986.4 kB/s eta 0:00:01
#      ------------ ------------------------- 307.2/960.7 kB 1.2 MB/s eta 0:00:01
#      ----------------- -------------------- 450.6/960.7 kB 1.4 MB/s eta 0:00:01
#      --------------------- ---------------- 532.5/960.7 kB 1.5 MB/s eta 0:00:01
#      --------------------------- ---------- 706.6/960.7 kB 1.7 MB/s eta 0:00:01
#      ----------------------------------- -- 901.1/960.7 kB 2.0 MB/s eta 0:00:01
# ...

# %%
pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.9 MB 1.3 MB/s eta 0:00:07
#       --------------------------------------- 0.1/8.9 MB 1.7 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/8.9 MB 1.8 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/8.9 MB 1.6 MB/s eta 0:00:06
#      - -------------------------------------- 0.4/8.9 MB 1.8 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/8.9 MB 1.7 MB/s eta 0:00:05
#      -- ------------------------------------- 0.6/8.9 MB 1.8 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.9 MB 2.0 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.9 MB 1.8 MB/s eta 0:00:05
# ...

# %%
pip install pypdf
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/249.5 kB ? eta -:--:--
#      - -------------------------------------- 10.2/249.5 kB ? eta -:--:--
#      - -------------------------------------- 10.2/249.5 kB ? eta -:--:--
#      --------- --------------------------- 61.4/249.5 kB 544.7 kB/s eta 0:00:01
#      ---------- -------------------------- 71.7/249.5 kB 491.5 kB/s eta 0:00:01
#      ------------- ----------------------- 92.2/249.5 kB 435.7 kB/s eta 0:00:01
#      ---------------- ------------------- 112.6/249.5 kB 467.6 kB/s eta 0:00:01
#      -------------------- --------------- 143.4/249.5 kB 472.1 kB/s eta 0:00:01
#      ---------------------- ------------- 153.6/249.5 kB 458.0 kB/s eta 0:00:01
#      ---------------------------- ------- 194.6/249.5 kB 512.0 kB/s eta 0:00:01
#      ----------------------------- ------ 204.8/249.5 kB 478.0 kB/s eta 0:00:01
# ...

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#      ----------------- ---------------------- 30.7/72.0 kB ? eta -:--:--
#      ----------------- ---------------------- 30.7/72.0 kB ? eta -:--:--
#      -------------------------------------- 72.0/72.0 kB 656.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyproject-toml
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/64.5 kB ? eta -:--:--
#      ------------------ ------------------- 30.7/64.5 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 64.5/64.5 kB 687.4 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install chromadb
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/86.6 kB ? eta -:--:--
#      -------------- ------------------------- 30.7/86.6 kB ? eta -:--:--
#      -------------- ------------------------- 30.7/86.6 kB ? eta -:--:--
#      -------------------------------------- 86.6/86.6 kB 820.9 kB/s eta 0:00:00
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/222.2 kB ? eta -:--:--
#      -------------- ------------------------ 81.9/222.2 kB 2.3 MB/s eta 0:00:01
#      ---------------- ---------------------- 92.2/222.2 kB 1.3 MB/s eta 0:00:01
# ...

# %%
# pip install pycryptodome==3.15.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.9 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.9 MB 960.0 kB/s eta 0:00:02
#      -- ------------------------------------- 0.1/1.9 MB 1.3 MB/s eta 0:00:02
#      -- ------------------------------------- 0.1/1.9 MB 1.2 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.2/1.9 MB 1.1 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.3/1.9 MB 1.1 MB/s eta 0:00:02
#      ------ --------------------------------- 0.3/1.9 MB 1.1 MB/s eta 0:00:02
#      -------- ------------------------------- 0.4/1.9 MB 1.2 MB/s eta 0:00:02
#      -------- ------------------------------- 0.4/1.9 MB 1.2 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.5/1.9 MB 1.2 MB/s eta 0:00:02
# ...

# %%
# # Import os to set API key
# import os
# # Import OpenAI as main LLM service
# from langchain.llms import OpenAI
# # Bring in streamlit for UI/app interface
# import streamlit as st

# # Import PDF document loaders...there's other ones as well!
# from langchain.document_loaders import PyPDFLoader
# # Import chroma as the vector store 
# from langchain.vectorstores import Chroma
# from langchain.chains.question_answering import load_qa_chain
# # Import vector store stuff
# from langchain.agents.agent_toolkits import (
#     create_vectorstore_agent,
#     VectorStoreToolkit,
#     VectorStoreInfo
# )

# # Set APIkey for OpenAI Service
# # Can sub this out for other LLM providers
# os.environ['OPENAI_API_KEY'] = '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'

# # Create instance of OpenAI LLM
# llm = OpenAI(temperature=0.5, verbose=True)

# # Create and load PDF Loader
# loader = PyPDFLoader('annualreport.pdf')
# # Split pages from pdf 
# pages = loader.load_and_split()
# # Load documents into vector database aka ChromaDB
# store = Chroma.from_documents(pages, collection_name='langchainTest')

# # Create vectorstore info object - metadata repo?
# vectorstore_info = VectorStoreInfo(
#     name="Book",
#     description="Book as a pdf",
#     vectorstore=store
# )
# # Convert the document store into a langchain toolkit
# toolkit = VectorStoreToolkit(vectorstore_info=vectorstore_info)

# # Add the toolkit to an end-to-end LC
# agent_executor = create_vectorstore_agent(
#     llm=llm,
#     toolkit=toolkit,
#     verbose=True
# )

# st.title('🦜🔗Writer\'s voice')
# # Create a text input box for the user
# prompt = st.text_input('Input your prompt here')
# prompt += '\n Answer from author\'s perspective placing yourself as the author'
# chain = load_qa_chain(llm, chain_type="stuff")
# # If the user hits enter
# if prompt:
#              # With a streamlit expander  
#     with st.expander('Document Similarity Search'):
#         # Find the relevant pages
#         search = store.similarity_search_with_score(prompt) 
#         # Write out the first 
#         st.write(search[0][0].page_content) 
#     # Then pass the prompt to the LLM
#     response = chain.run(input_documents=docs, question=prompt)
#     # ...and write it out to the screen
#     st.write(response)

# #     # With a streamlit expander  
# #     with st.expander('Document Similarity Search'):
# #         # Find the relevant pages
# #         search = store.similarity_search_with_score(prompt) 
# #         # Write out the first 
# #         st.write(search[0][0].page_content)

# %%
pip list
# Out:
# Package                 VersionNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ----------------------- --------
# aiohttp                 3.8.4
# aiosignal               1.3.1
# altair                  4.2.2
# anyio                   3.7.0
# asttokens               2.2.1
# async-timeout           4.0.2
# attrs                   23.1.0
# backcall                0.2.0
# backoff                 2.2.1
# blinker                 1.6.2
# cachetools              5.3.1
# certifi                 2023.5.7
# charset-normalizer      3.1.0
# chromadb                0.3.25
# click                   8.1.3
# clickhouse-connect      0.5.25
# colorama                0.4.6
# coloredlogs             15.0.1
# comm                    0.1.3
# dataclasses-json        0.5.7
# debugpy                 1.6.7
# decorator               5.1.1
# ...

# %%
pip install tiktoken
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/635.3 kB ? eta -:--:--
#      - ----------------------------------- 30.7/635.3 kB 640.0 kB/s eta 0:00:01
#      ---- -------------------------------- 71.7/635.3 kB 975.2 kB/s eta 0:00:01
#      ------ ----------------------------- 122.9/635.3 kB 901.1 kB/s eta 0:00:01
#      ------------ ------------------------- 204.8/635.3 kB 1.1 MB/s eta 0:00:01
#      -------------- ----------------------- 235.5/635.3 kB 1.0 MB/s eta 0:00:01
#      ------------------ ------------------- 307.2/635.3 kB 1.1 MB/s eta 0:00:01
#      --------------------- ---------------- 358.4/635.3 kB 1.2 MB/s eta 0:00:01
#      ------------------------- ------------ 430.1/635.3 kB 1.2 MB/s eta 0:00:01
#      ------------------------------ ------- 512.0/635.3 kB 1.2 MB/s eta 0:00:01
#      --------------------------------- ---- 563.2/635.3 kB 1.2 MB/s eta 0:00:01
# ...

# %%
def doc_summary(docs):
    print (f'You have {len(docs)} document(s)')
    
    num_words = sum([len(doc.page_content.split(' ')) for doc in docs])
    
    print (f'You have roughly {num_words} words in your docs')
    print ()
    print (f'Preview: \n{docs[0].page_content.split(". ")[0]}')

# %%
doc_summary(pages)

# %%
# Import os to set API key
import os
# Import OpenAI as main LLM service
from langchain.llms import OpenAI
# Bring in streamlit for UI/app interface
import streamlit as st
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
# Import PDF document loaders...there's other ones as well!
from langchain.document_loaders import PyPDFLoader
# Import chroma as the vector store 
from langchain.vectorstores import Chroma

# Import vector store stuff
from langchain.agents.agent_toolkits import (
    create_vectorstore_agent,
    VectorStoreToolkit,
    VectorStoreInfo
)

# Set APIkey for OpenAI Service
# Can sub this out for other LLM providers
os.environ['OPENAI_API_KEY'] = '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'

# Create instance of OpenAI LLM
llm = OpenAI(temperature=0.5, verbose=True)

# Create and load PDF Loader
loader = PyPDFLoader('Book.pdf')
# Split pages from pdf 
pages = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(pages)
embeddings = OpenAIEmbeddings(openai_api_key=os.environ['OPENAI_API_KEY'])
# Load documents into vector database aka ChromaDB
store = Chroma.from_documents(texts,embeddings, collection_name='GetRich')

# Create vectorstore info object - metadata repo?
vectorstore_info = VectorStoreInfo(
    name="General questions from a reader of the book",
    description="Kiyosaki's book",
    vectorstore=store
)
# Convert the document store into a langchain toolkit
toolkit = VectorStoreToolkit(vectorstore_info=vectorstore_info)

# Add the toolkit to an end-to-end LC
agent_executor = create_vectorstore_agent(
    llm=llm,
    toolkit=toolkit,
    verbose=True
)
# st.title('🦜🔗 GPT Investment Banker')
# # Create a text input box for the user
# prompt = st.text_input('Input your prompt here')

# # If the user hits enter
# if prompt:
#     # Then pass the prompt to the LLM
#     response = agent_executor.run(prompt)
#     # ...and write it out to the screen
#     st.write(response)

#     # With a streamlit expander  
#     with st.expander('Document Similarity Search'):
#         # Find the relevant pages
#         search = store.similarity_search_with_score(prompt) 
#         # Write out the first 
#         st.write(search[0][0].page_content)

# %%
#title('🦜🔗 GPT Investment Banker')
# Create a text input box for the user
prompt = input('Input your question here')
# add_prompt = "? Answer by getting into author\'s shoes"
# prompt = prompt + add_prompt

# Then pass the prompt to the LLM
response = agent_executor.run(prompt)
# ...and write it out to the screen
print(response)

search = store.similarity_search_with_score(prompt) 
# Write out the first 
print(search[0][0].page_content)
# Out:
# Input your question herewhat is wrong frank ? How can anyone change him?
#
#
# > Entering new AgentExecutor chain...
#  I need to find out what is wrong with Frank
# Action: General questions from a reader of the book
# Action Input: What is wrong with Frank?
# Observation:  Nothing is wrong with Frank.
# Thought: I need to find out how to change Frank
# Action: General questions from a reader of the book
# Action Input: How can anyone change Frank?
# Observation:  Frank cannot be changed. He is a mentor who has already given advice and it is up to the person to decide if they want to follow it or not.
# Thought: I now know the final answer
# Final Answer: Frank cannot be changed, but he can offer advice which the person can choose to follow or not.
#
# > Finished chain.
# Frank cannot be changed, but he can offer advice which the person can choose to follow or not.
# THE PUMPKIN PLAN
# 12heartbeat later, the president of a prestigious bank offered me a
# ...

# %%
# !streamlit hello
# Out:
# ^C

# %%
# !cd C:\Users\ggsag\Downloads

# %%
# !streamlit run C:\Users\ggsag\Desktop\Test 1\lchain1\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Streamlit requires raw Python (.py) files, but the provided file has no extension.
# For more information, please see https://docs.streamlit.io

# %%
# !streamlit run --help
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
#
#   Run a Python script, piping stderr to Streamlit.
#
#   The script can be local or it can be an url. In the latter case, Streamlit
#   will download the script to a temporary file and runs this file.
#
# Options:
#   --global.disableWatchdogWarning BOOLEAN
#                                   By default, Streamlit checks if the Python
#                                   watchdog module is available and, if not,
#                                   prints a warning asking for you to install
#                                   it. The watchdog module is not required, but
#                                   highly recommended. It improves Streamlit's
#                                   ability to detect changes to files in your
#                                   filesystem.
#
#                                   If you'd like to turn off this warning, set
#                                   this to True.  [env var:
# ...

# %%
# !jupyter nbconvert --to script Langchain_Tutorial.ipynb
# Out:
# [NbConvertApp] Converting notebook Langchain_Tutorial.ipynb to script
# [NbConvertApp] Writing 6204 bytes to Langchain_Tutorial.py

# %%
# !git clone https://github.com/nicknochnack/LangchainDocuments
